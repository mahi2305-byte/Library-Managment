# %%
dict = {"a" : 1 , "b" : 2 , "c" : 3 , "d" : 4}
# for i in dict:
#     print(dict[i])
for idx , i in enumerate(dict):
    print(idx , i , dict[i])
# Out:
# 0 a 1
# 1 b 2
# 2 c 3
# 3 d 4

# %% [markdown]
# # enumerate uses the indexes and basically we can acess multiple in same loop

# %%
fruits = ["apple" , "mango" , "banana" , "orange" , "grapes"]

for idx , i in enumerate(fruits): 
    
    print(idx , i)
# Out:
# 0 apple
# 1 mango
# 2 banana
# 3 orange
# 4 grapes

# %%
# using while loop 

x  = 0
while x < 5:
    x += 1 
    if x == 1:
        continue
    
    print ("value of x :" , x)
    
    
    # if x == 3:
    #     break
# Out:
# value of x : 2
# value of x : 3
# value of x : 4
# value of x : 5

# %%
# for i in range(start , stop , step):
for i in enumerate(fruits , start = 2):
    print(i)
# Out:
# (2, 'apple')
# (3, 'mango')
# (4, 'banana')
# (5, 'orange')
# (6, 'grapes')

# %%
students = [ "alice" , "bob" , "charlie" , "david"]
attendance = [ True , False , True , True]

# for idx , student in enumerate(students):
#     print(f"Roll {idx} :{student} - { "present" if attendance[idx] else "absent"}")
    
#!zip - allow iteration of two lists at same time 1

for idx , (student , status)in enumerate(zip(students , attendance)):
    # print (idx , student , status )
    print(f"Roll {idx} :{student} - { "present" if attendance[idx] else "absent"}")
# Out:
# Roll 0 :alice - present
# Roll 1 :bob - absent
# Roll 2 :charlie - present
# Roll 3 :david - present

# %%
x  =  1
for i in range (1,10):
    for j in range(1,4):
        print(f"{i} x {j} = {i*j}")
    print("---")
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# ---
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# ---
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# ---
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# ---
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# ---
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# ---
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# ---
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# ---
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# ---

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print("*" , end = '')
    i = i +1
    
print()
# Out:
# ***************

# %%
star = int(input("enter size of pyramid"))
for i in range (1,star+1,2):
    print (("*"*i).center(star))
for i in range (star -2 , 0 , -2):
    print((i*"*").center(star))
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************
#  ************
#   **********
#    ********
#     ******
#      ****
#       **

# %%
star = 5
for i in range(star):
    if i==0 or i == star-1:
        print("* "*star)
    else:
        print("*" + " "*(star + 2) + "*")
# Out:
# * * * * *
# *       *
# *       *
# *       *
# * * * * *

# %%
n = int(input("enter size"))

for i in range(n):
    for j in range(n):
        if i == 0 or i == n-1 or j == 0 or j == n-1:
            print("*" , end = ' ')
            
        else :
            print (" ", end = ' ')
    print()
# Out:
# * * * * * * * * * *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# * * * * * * * * * *

# %%
n = int(input("enter size"))
m = int(input("enter b"))

for i in range(n):
    for j in range(m):
        if i == 0 or i == n-1 or j == 0 or j == m-1:
            print("*" , end = ' ')
            
        else :
            print (" ", end = ' ')
    print()
# Out:
# * * * * * * * * * * * * * * *
# *                           *
# *                           *
# *                           *
# * * * * * * * * * * * * * * *
